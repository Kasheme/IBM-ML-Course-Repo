# %% [markdown]
# # Machine Learning Foundation
#
# ## Section 2, Part d:  Regularization and Gradient Descent

# %% [markdown]
# ## Introduction
#
# We will begin with a short tutorial on regression, polynomial features, and regularization based on a very simple, sparse data set that contains a column of `x` data and associated `y` noisy data. The data file is called `X_Y_Sinusoid_Data.csv`.

# %% [markdown]
# ## Question 1
#
# *   Import the data.
#
# *   Also generate approximately 100 equally spaced x data points over the range of 0 to 1. Using these points, calculate the y-data which represents the "ground truth" (the real function) from the equation: $y = sin(2\pi x)$
#
# *   Plot the sparse data (`x` vs `y`) and the calculated ("real") data.

# %%
# Surpress warnings from using older version of sklearn:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
import pandas as pd
import numpy as np


data = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML240EN-SkillsNetwork/labs/data/X_Y_Sinusoid_Data.csv")
data.head()

X_real = np.linspace(0, 1.0, 100)
Y_real = np.sin(2 * np.pi * X_real)

# %%
X_real
# Out:
# array([0.        , 0.01010101, 0.02020202, 0.03030303, 0.04040404,
#        0.05050505, 0.06060606, 0.07070707, 0.08080808, 0.09090909,
#        0.1010101 , 0.11111111, 0.12121212, 0.13131313, 0.14141414,
#        0.15151515, 0.16161616, 0.17171717, 0.18181818, 0.19191919,
#        0.2020202 , 0.21212121, 0.22222222, 0.23232323, 0.24242424,
#        0.25252525, 0.26262626, 0.27272727, 0.28282828, 0.29292929,
#        0.3030303 , 0.31313131, 0.32323232, 0.33333333, 0.34343434,
#        0.35353535, 0.36363636, 0.37373737, 0.38383838, 0.39393939,
#        0.4040404 , 0.41414141, 0.42424242, 0.43434343, 0.44444444,
#        0.45454545, 0.46464646, 0.47474747, 0.48484848, 0.49494949,
#        0.50505051, 0.51515152, 0.52525253, 0.53535354, 0.54545455,
#        0.55555556, 0.56565657, 0.57575758, 0.58585859, 0.5959596 ,
#        0.60606061, 0.61616162, 0.62626263, 0.63636364, 0.64646465,
#        0.65656566, 0.66666667, 0.67676768, 0.68686869, 0.6969697 ,
#        0.70707071, 0.71717172, 0.72727273, 0.73737374, 0.74747475,
#        0.75757576, 0.76767677, 0.77777778, 0.78787879, 0.7979798 ,
#        0.80808081, 0.81818182, 0.82828283, 0.83838384, 0.84848485,
#        0.85858586, 0.86868687, 0.87878788, 0.88888889, 0.8989899 ,
#        0.90909091, 0.91919192, 0.92929293, 0.93939394, 0.94949495,
#        0.95959596, 0.96969697, 0.97979798, 0.98989899, 1.        ])

# %%
Y_real
# Out:
# array([ 0.00000000e+00,  6.34239197e-02,  1.26592454e-01,  1.89251244e-01,
#         2.51147987e-01,  3.12033446e-01,  3.71662456e-01,  4.29794912e-01,
#         4.86196736e-01,  5.40640817e-01,  5.92907929e-01,  6.42787610e-01,
#         6.90079011e-01,  7.34591709e-01,  7.76146464e-01,  8.14575952e-01,
#         8.49725430e-01,  8.81453363e-01,  9.09631995e-01,  9.34147860e-01,
#         9.54902241e-01,  9.71811568e-01,  9.84807753e-01,  9.93838464e-01,
#         9.98867339e-01,  9.99874128e-01,  9.96854776e-01,  9.89821442e-01,
#         9.78802446e-01,  9.63842159e-01,  9.45000819e-01,  9.22354294e-01,
#         8.95993774e-01,  8.66025404e-01,  8.32569855e-01,  7.95761841e-01,
#         7.55749574e-01,  7.12694171e-01,  6.66769001e-01,  6.18158986e-01,
#         5.67059864e-01,  5.13677392e-01,  4.58226522e-01,  4.00930535e-01,
#         3.42020143e-01,  2.81732557e-01,  2.20310533e-01,  1.58001396e-01,
#         9.50560433e-02,  3.17279335e-02, -3.17279335e-02, -9.50560433e-02,
#        -1.58001396e-01, -2.20310533e-01, -2.81732557e-01, -3.42020143e-01,
#        -4.00930535e-01, -4.58226522e-01, -5.13677392e-01, -5.67059864e-01,
#        -6.18158986e-01, -6.66769001e-01, -7.12694171e-01, -7.55749574e-01,
#        -7.95761841e-01, -8.32569855e-01, -8.66025404e-01, -8.95993774e-01,
#        -9.22354294e-01, -9.45000819e-01, -9.63842159e-01, -9.78802446e-01,
#        -9.89821442e-01, -9.96854776e-01, -9.99874128e-01, -9.98867339e-01,
#        -9.93838464e-01, -9.84807753e-01, -9.71811568e-01, -9.54902241e-01,
#        -9.34147860e-01, -9.09631995e-01, -8.81453363e-01, -8.49725430e-01,
#        -8.14575952e-01, -7.76146464e-01, -7.34591709e-01, -6.90079011e-01,
#        -6.42787610e-01, -5.92907929e-01, -5.40640817e-01, -4.86196736e-01,
#        -4.29794912e-01, -3.71662456e-01, -3.12033446e-01, -2.51147987e-01,
#        -1.89251244e-01, -1.26592454e-01, -6.34239197e-02, -2.44929360e-16])

# %%
data.head()
# Out:
#           x         y
# 0  0.038571  0.066391
# 1  0.166776  1.027483
# 2  0.183153  1.245302
# 3  0.187359  1.004781
# 4  0.243116  1.264121

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
sns.set_style('white')
sns.set_context('talk')
sns.set_palette('dark')

# Plot of the noisy (sparse)
ax = data.set_index('x')['y'].plot(ls='', marker='o', label='data')
ax.plot(X_real, Y_real, ls='--', marker='', label='real function')

ax.legend()
ax.set(xlabel='x data', ylabel='y data');

# %% [markdown]
# ## Question 2
#
# *   Using the `PolynomialFeatures` class from Scikit-learn's preprocessing library, create 20th order polynomial features.
# *   Fit this data using linear regression.
# *   Plot the resulting predicted value compared to the calculated data.
#
# Note that `PolynomialFeatures` requires either a dataframe (with one column, not a Series) or a 2D array of dimension (`X`, 1), where `X` is the length.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Setup the polynomial features
degree = 20
pf = PolynomialFeatures(degree)
lr = LinearRegression()

# Extract the X- and Y- data from the dataframe 
X_data = data[['x']]
Y_data = data['y']

# Create the features and fit the model
X_poly = pf.fit_transform(X_data)
lr = lr.fit(X_poly, Y_data)
Y_pred = lr.predict(X_poly)

# Plot the result
plt.plot(X_data, Y_data, marker='o', ls='', label='data', alpha=1)
plt.plot(X_real, Y_real, ls='--', label='real function')
plt.plot(X_data, Y_pred, marker='^', alpha=.5, label='predictions w/ polynomial features')
plt.legend()
ax = plt.gca()
ax.set(xlabel='x data', ylabel='y data');

# %% [markdown]
# ## Question 3
#
# *   Perform the regression on using the data with polynomial features using ridge regression ($\alpha$=0.001) and lasso regression ($\alpha$=0.0001).
# *   Plot the results, as was done in Question 1.
# *   Also plot the magnitude of the coefficients obtained from these regressions, and compare them to those obtained from linear regression in the previous question. The linear regression coefficients will likely need a separate plot (or their own y-axis) due to their large magnitude.
#
# What does the comparatively large magnitude of the data tell you about the role of regularization?

# %%
# Mute the sklearn warning about regularization
import warnings
warnings.filterwarnings('ignore', module='sklearn')

from sklearn.linear_model import Ridge, Lasso

# The ridge regression model
rr = Ridge(alpha=0.001)
rr = rr.fit(X_poly, Y_data)
Y_pred_rr = rr.predict(X_poly)

# The lasso regression model
lassor = Lasso(alpha=0.0001)
lassor = lassor.fit(X_poly, Y_data)
Y_pred_lr = lassor.predict(X_poly)

# The plot of the predicted values
plt.plot(X_data, Y_data, marker='o', ls='', label='data')
plt.plot(X_real, Y_real, ls='--', label='real function')
plt.plot(X_data, Y_pred, label='linear regression', marker='^', alpha=.5)
plt.plot(X_data, Y_pred_rr, label='ridge regression', marker='^', alpha=.5)
plt.plot(X_data, Y_pred_lr, label='lasso regression', marker='^', alpha=.5)

plt.legend()

ax = plt.gca()
ax.set(xlabel='x data', ylabel='y data');

# %%
# let's look at the absolute value of coefficients for each model

coefficients = pd.DataFrame()
coefficients['linear regression'] = lr.coef_.ravel()
coefficients['ridge regression'] = rr.coef_.ravel()
coefficients['lasso regression'] = lassor.coef_.ravel()
coefficients = coefficients.applymap(abs)

coefficients.describe()  # Huge difference in scale between non-regularized vs regularized regression
# Out:
#        linear regression  ridge regression  lasso regression
# count       2.100000e+01         21.000000         21.000000
# mean        5.779558e+13          2.169397          2.167284
# std         5.984113e+13          2.900278          4.706731
# min         1.609210e+07          0.000000          0.000000
# 25%         3.399053e+12          0.467578          0.000000
# 50%         3.607116e+13          1.017272          0.252181
# 75%         1.066311e+14          2.883507          1.641353
# max         1.648543e+14         12.429635         20.176708

# %%
(coefficients>0).sum()
# Out:
# linear regression    21
# ridge regression     20
# lasso regression     15
# dtype: int64

# %%
colors = sns.color_palette()

# Setup the dual y-axes
ax1 = plt.axes()
ax2 = ax1.twinx()

# Plot the linear regression data
ax1.plot(lr.coef_.ravel(), 
         color=colors[0], marker='o', label='linear regression')

# Plot the regularization data sets
ax2.plot(rr.coef_.ravel(), 
         color=colors[1], marker='o', label='ridge regression')

ax2.plot(lassor.coef_.ravel(), 
         color=colors[2], marker='o', label='lasso regression')

# Customize axes scales
ax1.set_ylim(-2e14, 2e14)
ax2.set_ylim(-25, 25)

# Combine the legends
h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1+h2, l1+l2)

ax1.set(xlabel='coefficients',ylabel='linear regression')
ax2.set(ylabel='ridge and lasso regression')

ax1.set_xticks(range(len(lr.coef_)));

# %% [markdown]
# ## Question 4
#
# For the remaining questions, we will be working with the [data set](https://www.kaggle.com/c/house-prices-advanced-regression-techniques?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) from last lesson, which is based on housing prices in Ames, Iowa. There are an extensive number of features--see the exercises from week three for a discussion of these features.
#
# To begin:
#
# *   Import the data with Pandas, remove any null values, and one hot encode categoricals. Either Scikit-learn's feature encoders or Pandas `get_dummies` method can be used.
# *   Split the data into train and test sets.
# *   Log transform skewed features.
# *   Scaling can be attempted, although it can be interesting to see how well regularization works without scaling features.

# %%
data = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML240EN-SkillsNetwork/labs/data/Ames_Housing_Sales.csv")
data.head(10)
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0     856.0     854.0        0.0   NaN             3     1Fam       TA
# 1    1262.0       0.0        0.0   NaN             3     1Fam       TA
# 2     920.0     866.0        0.0   NaN             3     1Fam       TA
# 3     961.0     756.0        0.0   NaN             3     1Fam       Gd
# 4    1145.0    1053.0        0.0   NaN             4     1Fam       TA
# 5     796.0     566.0      320.0   NaN             1     1Fam       TA
# 6    1694.0       0.0        0.0   NaN             3     1Fam       TA
# 7    1107.0     983.0        0.0   NaN             3     1Fam       TA
# 8    1022.0     752.0        0.0   NaN             2     1Fam      NaN
# 9    1077.0       0.0        0.0   NaN             2   2fmCon       TA
#
#   BsmtExposure  BsmtFinSF1  BsmtFinSF2  ... ScreenPorch Street  TotRmsAbvGrd  \
# 0           No       706.0         0.0  ...         0.0   Pave             8
# 1           Gd       978.0         0.0  ...         0.0   Pave             6
# 2           Mn       486.0         0.0  ...         0.0   Pave             6
# 3           No       216.0         0.0  ...         0.0   Pave             7
# 4           Av       655.0         0.0  ...         0.0   Pave             9
# 5           No       732.0         0.0  ...         0.0   Pave             5
# 6           Av      1369.0         0.0  ...         0.0   Pave             7
# 7           Mn       859.0        32.0  ...         0.0   Pave             7
# 8          NaN         0.0         0.0  ...         0.0   Pave             8
# 9           No       851.0         0.0  ...         0.0   Pave             5
#
#    TotalBsmtSF Utilities  WoodDeckSF YearBuilt YearRemodAdd YrSold SalePrice
# 0        856.0    AllPub         0.0      2003         2003   2008  208500.0
# 1       1262.0    AllPub       298.0      1976         1976   2007  181500.0
# 2        920.0    AllPub         0.0      2001         2002   2008  223500.0
# 3        756.0    AllPub         0.0      1915         1970   2006  140000.0
# 4       1145.0    AllPub       192.0      2000         2000   2008  250000.0
# 5        796.0    AllPub        40.0      1993         1995   2009  143000.0
# 6       1686.0    AllPub       255.0      2004         2005   2007  307000.0
# 7       1107.0    AllPub       235.0      1973         1973   2009  200000.0
# 8        952.0    AllPub        90.0      1931         1950   2008  129900.0
# 9        991.0    AllPub         0.0      1939         1950   2008  118000.0
#
# [10 rows x 80 columns]

# %% [markdown]
# Create a list of categorial data and one-hot encode. Pandas one-hot encoder (`get_dummies`) works well with data that is defined as a categorical.

# %%
# Get a Pd.Series consisting of all the string categoricals
one_hot_encode_cols = data.dtypes[data.dtypes == np.object]  # filtering by string categoricals
one_hot_encode_cols = one_hot_encode_cols.index.tolist()  # list of categorical fields

# Here we see another way of one-hot-encoding:
# Encode these columns as categoricals so one hot encoding works on split data (if desired)
for col in one_hot_encode_cols:
    data[col] = pd.Categorical(data[col])

# Do the one hot encoding
data = pd.get_dummies(data, columns=one_hot_encode_cols)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5284\541837702.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   one_hot_encode_cols = data.dtypes[data.dtypes == np.object]  # filtering by string categoricals

# %% [markdown]
# Next, split the data in train and test data sets.

# %%
data.columns
# Out:
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'BedroomAbvGr', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtFullBath', 'BsmtHalfBath', 'BsmtUnfSF',
#        'EnclosedPorch',
#        ...
#        'SaleType_ConLD', 'SaleType_ConLI', 'SaleType_ConLw', 'SaleType_New',
#        'SaleType_Oth', 'SaleType_WD', 'Street_Grvl', 'Street_Pave',
#        'Utilities_AllPub', 'Utilities_NoSeWa'],
#       dtype='object', length=284)

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.3, random_state=42)

# %% [markdown]
# There are a number of columns that have skewed features--a log transformation can be applied to them. Note that this includes the `SalePrice`, our predictor. However, let's keep that one as is.

# %%
# Create a list of float colums to check for skewing
mask = data.dtypes == np.float
float_cols = data.columns[mask]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5284\2592716327.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = data.dtypes == np.float

# %%
# Create a list of columns that are not one hot encoded (1s and 0s)
mask = data.apply(lambda x: x.nunique()) > 2
num_cols = data.columns[mask]
num_cols
# Out:
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'BedroomAbvGr', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtFullBath', 'BsmtHalfBath', 'BsmtUnfSF',
#        'EnclosedPorch', 'Fireplaces', 'FullBath', 'GarageArea', 'GarageCars',
#        'GarageYrBlt', 'GrLivArea', 'HalfBath', 'KitchenAbvGr', 'LotArea',
#        'LotFrontage', 'LowQualFinSF', 'MSSubClass', 'MasVnrArea', 'MiscVal',
#        'MoSold', 'OpenPorchSF', 'OverallCond', 'OverallQual', 'PoolArea',
#        'ScreenPorch', 'TotRmsAbvGrd', 'TotalBsmtSF', 'WoodDeckSF', 'YearBuilt',
#        'YearRemodAdd', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
skew_limit = 0.75
skew_vals = train[float_cols].skew()

skew_cols = (skew_vals
             .sort_values(ascending=False)
             .to_frame()
             .rename(columns={0:'Skew'})
             .query('abs(Skew) > {0}'.format(skew_limit)))

skew_cols
# Out:
#                     Skew
# MiscVal        26.915364
# PoolArea       15.777668
# LotArea        11.501694
# LowQualFinSF   11.210638
# 3SsnPorch      10.150612
# ScreenPorch     4.599803
# BsmtFinSF2      4.466378
# EnclosedPorch   3.218303
# LotFrontage     3.138032
# MasVnrArea      2.492814
# OpenPorchSF     2.295489
# SalePrice       2.106910
# BsmtFinSF1      2.010766
# TotalBsmtSF     1.979164
# 1stFlrSF        1.539692
# GrLivArea       1.455564
# WoodDeckSF      1.334388
# BsmtUnfSF       0.900308
# GarageArea      0.838422
# 2ndFlrSF        0.773655

# %% [markdown]
# Transform all the columns where the skew is greater than 0.75, excluding "SalePrice".

# %%
# OPTIONAL: Let's look at what happens to one of these features, when we apply np.log1p visually.

field = "BsmtFinSF1"
fig, (ax_before, ax_after) = plt.subplots(1, 2, figsize=(10, 5))
train[field].hist(ax=ax_before)
# np.log1p converts 0s to a 1 before doing the log transform to avoid errors
train[field].apply(np.log1p).hist(ax=ax_after)
ax_before.set(title='before np.log1p', ylabel='frequency', xlabel='value')
ax_after.set(title='after np.log1p', ylabel='frequency', xlabel='value')
fig.suptitle('Field "{}"'.format(field));
# a little bit better

# %%
# Mute the setting wtih a copy warnings
pd.options.mode.chained_assignment = None

for col in skew_cols.index.tolist():
    if col == "SalePrice":
        continue
    train[col] = np.log1p(train[col])
    test[col]  = test[col].apply(np.log1p)  # same thing

# %% [markdown]
# Separate features from predictor.

# %%
feature_cols = [x for x in train.columns if x != 'SalePrice']
X_train = train[feature_cols]
y_train = train['SalePrice']

X_test  = test[feature_cols]
y_test  = test['SalePrice']

# %% [markdown]
# ## Question 5
#
# *   Write a function **`rmse`** that takes in truth and prediction values and returns the root-mean-squared error. Use sklearn's `mean_squared_error`.

# %%
from sklearn.metrics import mean_squared_error


def rmse(ytrue, ypredicted):
    return np.sqrt(mean_squared_error(ytrue, ypredicted))

# %% [markdown]
# *   Fit a basic linear regression model
# *   print the root-mean-squared error for this model
# *   plot the predicted vs actual sale price based on the model.

# %%
from sklearn.linear_model import LinearRegression

linearRegression = LinearRegression().fit(X_train, y_train)

linearRegression_rmse = rmse(y_test, linearRegression.predict(X_test))

print(linearRegression_rmse)
# Out:
# 947309.70442022

# %%
f = plt.figure(figsize=(6,6))
ax = plt.axes()

ax.plot(y_test, linearRegression.predict(X_test), 
         marker='o', ls='', ms=3.0)

lim = (0, y_test.max())

ax.set(xlabel='Actual Price', 
       ylabel='Predicted Price', 
       xlim=lim,
       ylim=lim,
       title='Linear Regression Results');

# %% [markdown]
# ## Question 6
#
# Ridge regression uses L2 normalization to reduce the magnitude of the coefficients. This can be helpful in situations where there is high variance. The regularization functions in Scikit-learn each contain versions that have cross-validation built in.
#
# *   Fit a regular (non-cross validated) Ridge model to a range of $\alpha$ values and plot the RMSE using the cross validated error function you created above.
# *   Use $$\[0.005, 0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 30, 80]$$ as the range of alphas.
# *   Then repeat the fitting of the Ridge models using the range of $\alpha$ values from the prior section. Compare the results.

# %% [markdown]
# Now for the `RidgeCV` method. It's not possible to get the alpha values for the models that weren't selected, unfortunately. The resulting error values and $\alpha$ values are very similar to those obtained above.

# %%
from sklearn.linear_model import RidgeCV

alphas = [0.005, 0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 30, 80]

ridgeCV = RidgeCV(alphas=alphas, 
                  cv=4).fit(X_train, y_train)

ridgeCV_rmse = rmse(y_test, ridgeCV.predict(X_test))

print(ridgeCV.alpha_, ridgeCV_rmse)
# Out:
# 15.0 32195.77826017293

# %% [markdown]
# ## Question 7
#
# Much like the `RidgeCV` function, there is also a `LassoCV` function that uses an L1 regularization function and cross-validation. L1 regularization will selectively shrink some coefficients, effectively performing feature elimination.
#
# The `LassoCV` function does not allow the scoring function to be set. However, the custom error function (`rmse`) created above can be used to evaluate the error on the final model.
#
# Similarly, there is also an elastic net function with cross validation, `ElasticNetCV`, which is a combination of L2 and L1 regularization.
#
# *   Fit a Lasso model using cross validation and determine the optimum value for $\alpha$ and the RMSE using the function created above. Note that the magnitude of $\alpha$ may be different from the Ridge model.
# *   Repeat this with the Elastic net model.
# *   Compare the results via table and/or plot.
#
# Use the following alphas:\
# `[1e-5, 5e-5, 0.0001, 0.0005]`

# %%
from sklearn.linear_model import LassoCV

alphas2 = np.array([1e-5, 5e-5, 0.0001, 0.0005])

lassoCV = LassoCV(alphas=alphas2,
                  max_iter=50000,
                  cv=3).fit(X_train, y_train)

lassoCV_rmse = rmse(y_test, lassoCV.predict(X_test))

print(lassoCV.alpha_, lassoCV_rmse)  # Lasso is slower

# %% [markdown]
# We can determine how many of these features remain non-zero.

# %%
print('Of {} coefficients, {} are non-zero with Lasso.'.format(len(lassoCV.coef_), 
                                                               len(lassoCV.coef_.nonzero()[0])))
# Out:
# Of 283 coefficients, 264 are non-zero with Lasso.

# %% [markdown]
# Now try the elastic net, with the same alphas as in Lasso, and l1\_ratios between 0.1 and 0.9

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
from sklearn.linear_model import ElasticNetCV

l1_ratios = np.linspace(0.1, 0.9, 9)

elasticNetCV = ElasticNetCV(alphas=alphas2, 
                            l1_ratio=l1_ratios,
                            max_iter=10000).fit(X_train, y_train)
elasticNetCV_rmse = rmse(y_test, elasticNetCV.predict(X_test))

print(elasticNetCV.alpha_, elasticNetCV.l1_ratio_, elasticNetCV_rmse)
# Out:
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50050852573.69809, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142798451322.33624, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162611696225.05774, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 601766681.6776123, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 123244559029.87282, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134683947934.6279, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39649885529.58331, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 135141412366.74646, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143348844885.6191, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10486899060.094604, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162559399361.35464, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 176283484866.65576, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2555733099.5090637, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 123923983869.24677, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152536702925.07785, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51132005829.79617, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137368370361.3908, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162446779441.54404, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1866534636.7068481, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120250614052.19513, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134528314687.96954, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41889732159.52565, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132201339853.1221, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143252048803.16812, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12053370841.592438, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 158417403798.1122, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 176137555507.90118, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2121734482.8146362, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120206072418.48114, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152347319612.09442, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64380786958.228485, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140569926295.85925, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162273523418.71323, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8938383552.078766, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 122916200121.7409, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134361082307.59969, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54979877129.42467, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133123650261.00333, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143142517577.15933, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19937242219.340027, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 158853356206.5928, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175981698926.95624, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5017659953.181091, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 123855015956.76959, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152143447195.36237, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81765518684.77545, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 144824340490.49756, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162079104438.6769, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32430633625.183716, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 124468684651.14548, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134169188022.11284, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75242086666.1391, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134517837556.61653, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143007613470.43796, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 68359881788.0531, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 160766666472.27927, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175805821648.6263, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22365907285.618225, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 130628812344.77298, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151906404441.5245, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98687390495.48628, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 148453076048.87152, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161841088198.4832, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64729394664.1702, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127347266691.27469, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133928765529.8357, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 95260715235.44884, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137005033004.7317, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142870954396.88287, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97061127857.85371, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 164627879164.42783, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175591237466.09396, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62122887067.566925, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137141869531.29585, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151601987807.38638, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118604694629.20961, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151131689128.59427, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161513972279.73157, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98453042202.59024, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 128389162411.57965, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133591038222.35318, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 121142226592.1984, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137355739477.32544, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142694328607.88788, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136333760579.99994, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 167590209197.62057, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175298200616.41592, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 103991667064.51886, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140194500912.94104, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151158093495.78384, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143829427768.11658, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153050636166.89096, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 160990563508.90903, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119518329954.67535, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127556914531.5775, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133033265965.42633, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132839135902.52557, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 135484422405.28375, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142443959980.40674, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 154808614205.7694, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 168972596502.3895, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 174825675139.59634, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 130172046932.47696, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140912655258.5708, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 150392551642.19638, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153613428868.73392, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153648124751.86246, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 159960929483.93002, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 128647668071.02765, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125769804777.91603, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 131925969786.62442, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138899556072.32614, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 135669453049.20253, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142035993700.47116, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 167075386166.73624, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 169678323416.20996, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173845385978.24506, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140681616493.5571, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140454343196.66583, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151041766152.77838, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 80551798945.74611, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 154991963258.5065, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153436556860.2674, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161835002242.6641, tolerance: 487372561.3038373
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 67284932232.01935, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 128560008728.91513, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125790645367.73283, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 128878641526.25491, tolerance: 465192498.4087123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79641607142.70721, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138572994566.0718, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136669156687.14044, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140575577935.454, tolerance: 464569448.37652475
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107438483225.82806, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 170223876626.31058, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 169405354811.23642, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175451935423.31247, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98212014126.1041, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142555795777.68622, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 139856522948.18182, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\User\miniconda3\envs\snowflakes\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151734589285.77417, tolerance: 488440735.70750004
#   model = cd_fast.enet_coordinate_descent_gram(
# 0.0005 0.1 35009.07612625834

# %% [markdown]
# Comparing the RMSE calculation from all models is easiest in a table.

# %%
rmse_vals = [linearRegression_rmse, ridgeCV_rmse, lassoCV_rmse, elasticNetCV_rmse]

labels = ['Linear', 'Ridge', 'Lasso', 'ElasticNet']

rmse_df = pd.Series(rmse_vals, index=labels).to_frame()
rmse_df.rename(columns={0: 'RMSE'}, inplace=1)
rmse_df
# Out:
#                      RMSE
# Linear      947309.704420
# Ridge        32195.778260
# Lasso        37753.025305
# ElasticNet   35009.076126

# %% [markdown]
# We can also make a plot of actual vs predicted housing prices as before.

# %%
f = plt.figure(figsize=(6,6))
ax = plt.axes()

labels = ['Ridge', 'Lasso', 'ElasticNet']

models = [ridgeCV, lassoCV, elasticNetCV]

for mod, lab in zip(models, labels):
    ax.plot(y_test, mod.predict(X_test), 
             marker='o', ls='', ms=3.0, label=lab)


leg = plt.legend(frameon=True)
leg.get_frame().set_edgecolor('black')
leg.get_frame().set_linewidth(1.0)

ax.set(xlabel='Actual Price', 
       ylabel='Predicted Price', 
       title='Linear Regression Results');

# %% [markdown]
# ## Question 8
#
# Let's explore Stochastic gradient descent in this exercise.\
# Recall that Linear models in general are sensitive to scaling.
# However, SGD is *very* sensitive to scaling.\
# Moreover, a high value of learning rate can cause the algorithm to diverge, whereas a too low value may take too long to converge.
#
# *   Fit a stochastic gradient descent model without a regularization penalty (the relevant parameter is `penalty`).
# *   Now fit stochastic gradient descent models with each of the three penalties (L2, L1, Elastic Net) using the parameter values determined by cross validation above.
# *   Do not scale the data before fitting the model.
# *   Compare the results to those obtained without using stochastic gradient descent.

# %%
# Import SGDRegressor and prepare the parameters

from sklearn.linear_model import SGDRegressor

model_parameters_dict = {
    'Linear': {'penalty': 'none'},
    'Lasso': {'penalty': 'l2',
           'alpha': lassoCV.alpha_},
    'Ridge': {'penalty': 'l1',
           'alpha': ridgeCV_rmse},
    'ElasticNet': {'penalty': 'elasticnet', 
                   'alpha': elasticNetCV.alpha_,
                   'l1_ratio': elasticNetCV.l1_ratio_}
}

new_rmses = {}
for modellabel, parameters in model_parameters_dict.items():
    # following notation passes the dict items as arguments
    SGD = SGDRegressor(**parameters)
    SGD.fit(X_train, y_train)
    new_rmses[modellabel] = rmse(y_test, SGD.predict(X_test))

rmse_df['RMSE-SGD'] = pd.Series(new_rmses)
rmse_df

# %% [markdown]
# Notice how high the error values are! The algorithm is diverging. This can be due to scaling and/or learning rate being too high. Let's adjust the learning rate and see what happens.
#
# *   Pass in `eta0=1e-7` when creating the instance of `SGDClassifier`.
# *   Re-compute the errors for all the penalties and compare.

# %%
# Import SGDRegressor and prepare the parameters

from sklearn.linear_model import SGDRegressor

model_parameters_dict = {
    'Linear': {'penalty': 'none'},
    'Lasso': {'penalty': 'l2',
           'alpha': lassoCV.alpha_},
    'Ridge': {'penalty': 'l1',
           'alpha': ridgeCV_rmse},
    'ElasticNet': {'penalty': 'elasticnet', 
                   'alpha': elasticNetCV.alpha_,
                   'l1_ratio': elasticNetCV.l1_ratio_}
}

new_rmses = {}
for modellabel, parameters in model_parameters_dict.items():
    # following notation passes the dict items as arguments
    SGD = SGDRegressor(eta0=1e-7, **parameters)
    SGD.fit(X_train, y_train)
    new_rmses[modellabel] = rmse(y_test, SGD.predict(X_test))

rmse_df['RMSE-SGD-learningrate'] = pd.Series(new_rmses)
rmse_df

# %% [markdown]
# Now let's scale our training data and try again.
#
# *   Fit a `MinMaxScaler` to `X_train` create a variable `X_train_scaled`.
# *   Using the scaler, transform `X_test` and create a variable `X_test_scaled`.
# *   Apply the same versions of SGD to them and compare the results. Don't pass in a eta0 this time.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

new_rmses = {}
for modellabel, parameters in model_parameters_dict.items():
    # following notation passes the dict items as arguments
    SGD = SGDRegressor(**parameters)
    SGD.fit(X_train_scaled, y_train)
    new_rmses[modellabel] = rmse(y_test, SGD.predict(X_test_scaled))

rmse_df['RMSE-SGD-scaled'] = pd.Series(new_rmses)
rmse_df

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

new_rmses = {}
for modellabel, parameters in model_parameters_dict.items():
    # following notation passes the dict items as arguments
    SGD = SGDRegressor(**parameters)
    SGD.fit(X_train_scaled, y_train)
    new_rmses[modellabel] = rmse(y_test, SGD.predict(X_test_scaled))

rmse_df['RMSE-SGD-scaled'] = pd.Series(new_rmses)
rmse_df

# %% [markdown]
# ***
#
# ### Machine Learning Foundation (C) 2020 IBM Corporation
